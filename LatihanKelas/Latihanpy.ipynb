# %%
print ("Nama: Ikzan Musyawir")
print ("NIm: 240210501022")
# Out:
# Nama: Ikzan Musyawir
# NIm: 240210501022

# %%
print("Hello World!")
print("I am learning Python.")
print("It is awesome!")
# Out:
# Hello World!
# I am learning Python.
# It is awesome!

# %% [markdown]
# ### Analisis
#
# Kode tersebut
