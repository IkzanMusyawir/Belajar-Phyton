# %%
mahasiswa = ["Darmawati","Tru Lutfiah","Elsa","Stevano"]
mahasiswa.append("arya")
mahasiswa.insert(3, "adit")
mahasiswa.pop()
mahasiswa.sort(reverse=True)
mahasiswa.remove("Elsa")

i=1

for nama in mahasiswa:
    print ("nama Mahasiswa ke -", i ,": ", nama)
    i += 1
print(mahasiswa)

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[2:5])

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[:5])

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[2:3])

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[1:3])

# %%
i = 1
while i <= 13:
    if i == 7:
        print ("WOW")
    else:
        print(i)
    i += 2

# %%
i = 1
while i <= 10:
    if i <= 8:
        print("hidup")
        print("Mahasiswa")
        i += 2
    else:
        print(i)
        i += 1

# %%
i = 1
while i <= 10:
    if i <= 8:
        print("hidup")
        print("Mahasiswa")
        i += 2
    else:
        print(i)
        i += 1
